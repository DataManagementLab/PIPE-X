# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Imputer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODELS = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

EXPERIMENT_NAME = 'sc_imputer_redundant_minimal'
EXPERIMENT_DATA_MIN = 'adult_noisy_0.000000'
EXPERIMENT_DATA_MAX = 'adult_noisy_0.800000'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_imputer_redundant_minimal.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                      experiment               dataset model  \
# 0   sc_imputer_redundant_minimal_adult_0.000000  adult_noisy_0.000000    DT
# 1   sc_imputer_redundant_minimal_adult_0.000000  adult_noisy_0.000000   GBT
# 2   sc_imputer_redundant_minimal_adult_0.000000  adult_noisy_0.000000   HGB
# 3   sc_imputer_redundant_minimal_adult_0.040000  adult_noisy_0.040000    DT
# 4   sc_imputer_redundant_minimal_adult_0.040000  adult_noisy_0.040000   GBT
# ..                                          ...                   ...   ...
# 58  sc_imputer_redundant_minimal_adult_0.760000  adult_noisy_0.760000   GBT
# 59  sc_imputer_redundant_minimal_adult_0.760000  adult_noisy_0.760000   HGB
# 60  sc_imputer_redundant_minimal_adult_0.800000  adult_noisy_0.800000    DT
# 61  sc_imputer_redundant_minimal_adult_0.800000  adult_noisy_0.800000   GBT
# 62  sc_imputer_redundant_minimal_adult_0.800000  adult_noisy_0.800000   HGB
#
#     sample_size status  \
# 0           100     OK
# 1           100     OK
# 2           100     OK
# 3           100     OK
# 4           100     OK
# ..          ...    ...
# 58          100     OK
# 59          100     OK
# 60          100     OK
# 61          100     OK
# 62          100     OK
#
#                                                                                                                                                                                                                                                                                                          aggregated_impacts
# 0                     {'immediate_impact': [0.4325608317406508, 0.017595506008880376, -0.005309351168514205, -0.032202019760637884, 0.10030157993925534, 0.4870534532403655], 'leave_out_impact': [0.6038873463058049, 0.6241885507904333, 0.6187403710771971, 0.4847973032707274, 0.5668489464837688, 0.5747822803733944]}
# 1                       {'immediate_impact': [0.3327805048419491, -0.006274618268144234, 0.04286883506468349, 0.015570765357722713, 0.21194874118692023, 0.4031057718168688], 'leave_out_impact': [0.5872782173043296, 0.6076560394680712, 0.5508634310568847, 0.3809498181193165, 0.5781448899233317, 0.5787035486273144]}
# 2                       {'immediate_impact': [0.4663219949336434, 0.027971873918269257, 0.03323176960965073, -0.06530600389223915, 0.13688456656142545, 0.40089579886925025], 'leave_out_impact': [0.584396889461054, 0.5801344039217203, 0.45364834773868445, 0.5153105322340041, 0.5172363246739315, 0.4679305020839437]}
# 3                     {'immediate_impact': [0.5006819658851016, 0.04840261493564091, -0.08741299648263896, 0.022490425663372757, 0.1568116081188394, 0.3590263818796844], 'leave_out_impact': [0.31662914929565505, 0.39739408875761717, 0.3368647388612894, 0.3529747015840361, 0.20050638561817236, 0.32185897303179367]}
# 4                    {'immediate_impact': [0.35349641180908276, 0.007518478391057478, 0.23630935888993468, 0.026757994801290937, -0.048978629455838814, 0.42489638556447307], 'leave_out_impact': [0.5967334755843601, 0.8131975101380288, 0.5752648592375417, 0.4316563678502104, 0.5934359819463243, 0.5954651141637626]}
# ..                                                                                                                                                                                                                                                                                                                      ...
# 58        {'immediate_impact': [0.12399502944312005, 0.8492941796183573, -0.02212618032585858, 0.004210053774107353, 0.03836019206197351, 0.006266725428300447], 'leave_out_impact': [0.06802835641110691, -0.054885726675463556, 0.0709226511443958, 0.0016071074343238269, -0.004580656660117333, -0.004461542402138625]}
# 59  {'immediate_impact': [0.06559796707616748, 0.9426447240549379, -0.044839319322387626, 0.02961235546615899, -0.00041864762037474633, 0.00740292034549786], 'leave_out_impact': [-0.0017550657314454436, -0.28277341865494365, -0.0016502117354699163, 0.006919591915430318, 0.0053077175809716015, 0.05159579942209143]}
# 60        {'immediate_impact': [0.014059831098934309, 0.9399142069082289, 0.021222265198949906, -0.0014111474393558728, 0.00358077340385045, 0.022634070829392294], 'leave_out_impact': [0.02230499217725341, -0.11229575227567672, 0.027923513578784132, 0.009676155832203328, 0.046012577716372446, 0.05815210637149232]}
# 61      {'immediate_impact': [0.006633274013799787, 0.9954011248924356, -0.038966310492210825, 0.007379901711548087, 0.02276123035685004, 0.00679077951757681], 'leave_out_impact': [0.04254966982610763, -0.10420395727900574, 0.010238037089727595, 0.0006762392802614466, -0.022079957786066664, -0.017461992311766886]}
# 62         {'immediate_impact': [0.03795861057072142, 0.96171432710959, -0.014187970289320558, 0.010298715177576086, 0.008172980405950995, -0.003956662974517742], 'leave_out_impact': [0.01002587742584384, -0.2319207261016809, 0.0015808332350545086, 0.0030752365902698606, 0.008517428102923583, 0.02979368815237022]}
#
# [63 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA_MIN,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.800000',
                                    dataset=EXPERIMENT_DATA_MAX,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_imputer_redundant_minimal_adult_0.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_imputer/sc_imputer_redundant_minimal.pkl
#
# Sample size: 100
# Samples: [588, 726, 726, 820, 843, 911, 1020, 1080, 1954, 1966, 1966, 1966, 2573, 2620, 2620, 5014, 5463, 5463, 6184, 6243, 6243, 6243, 7703, 8376, 8771, 8923, 9089, 9535, 9971, 10246, 10739, 10739, 10889, 10889, 11268, 11953, 11953, 11989, 13003, 13814, 14164, 14369, 14847, 15275, 15275, 16445, 16445, 16783, 17351, 17351, 17603, 17615, 17832, 18664, 18825, 18825, 18999, 19146, 19835, 20045, 20045, 20286, 20343, 20533, 21231, 21727, 21841, 23291, 23291, 23332, 24161, 24267, 24373, 24373, 24407, 25040, 25357, 25462, 25488, 25488, 26366, 26775, 26775, 26985, 27537, 27633, 28023, 28023, 28080, 28201, 28315, 28333, 29521, 29670, 30129, 30950, 31309, 31585, 31990, 32534]
# Pipeline steps: education-num_imputer, capital-gain_imputer, race_encoder, race_imputer, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.4663219949336434, 0.027971873918269257, 0.03323176960965073, -0.06530600389223915, 0.13688456656142545, 0.40089579886925025], 'leave_out_impact': [0.584396889461054, 0.5801344039217203, 0.45364834773868445, 0.5153105322340041, 0.5172363246739315, 0.4679305020839437]}
# F1 immediate_impact: 0.7175925925925926, 0.7237843202117102, 0.7215738579526508, 0.7191531591134634, 0.721214120752227, 0.720265780730897, 0.7215064420218038
# F1 leave_out_impact: 0.7188328912466844, 0.7176234979973297, 0.7209533267130089, 0.7221485411140584, 0.7191531591134634, 0.7242634889109566
#          What?  CPU Cycles    Seconds
# 0         Init    0.028917   0.028917
# 1        Setup  589.195423  24.269322
# 2  Avg per Run    6.195352   0.096849
# 3    Total Run  619.535223   9.684938
# Changes caused by each step:
#                     Step  \
# 0  education-num_imputer
# 1   capital-gain_imputer
# 2           race_imputer
# 3    categorical_imputer
# 4      numerical_imputer
# 5       numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                                                                                  -
# 2                                                                                                                                                                  -
# 3                                                                                                                                                                  -
# 4                                                                                                                              occupation, workclass, native-country
# 5  hours-per-week, sex, workclass, capital-gain, race, native-country, age, marital-status, capital-loss, fnlwgt, occupation, relationship, education, education-num
#
#    No of rows
# 0           0
# 1           0
# 2           0
# 3           0
# 4        1927
# 5       26048
# Name: sc_imputer_redundant_minimal_adult_0.800000
# Dataset: adult_noisy_0.800000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_imputer/sc_imputer_redundant_minimal.pkl
#
# Sample size: 100
# Samples: [588, 726, 726, 820, 843, 911, 1020, 1080, 1954, 1966, 1966, 1966, 2573, 2620, 2620, 5014, 5463, 5463, 6184, 6243, 6243, 6243, 7703, 8376, 8771, 8923, 9089, 9535, 9971, 10246, 10739, 10739, 10889, 10889, 11268, 11953, 11953, 11989, 13003, 13814, 14164, 14369, 14847, 15275, 15275, 16445, 16445, 16783, 17351, 17351, 17603, 17615, 17832, 18664, 18825, 18825, 18999, 19146, 19835, 20045, 20045, 20286, 20343, 20533, 21231, 21727, 21841, 23291, 23291, 23332, 24161, 24267, 24373, 24373, 24407, 25040, 25357, 25462, 25488, 25488, 26366, 26775, 26775, 26985, 27537, 27633, 28023, 28023, 28080, 28201, 28315, 28333, 29521, 29670, 30129, 30950, 31309, 31585, 31990, 32534]
# Pipeline steps: education-num_imputer, capital-gain_imputer, race_encoder, race_imputer, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.03795861057072142, 0.96171432710959, -0.014187970289320558, 0.010298715177576086, 0.008172980405950995, -0.003956662974517742], 'leave_out_impact': [0.01002587742584384, -0.2319207261016809, 0.0015808332350545086, 0.0030752365902698606, 0.008517428102923583, 0.02979368815237022]}
# F1 immediate_impact: 0.6644067796610169, 0.6589986468200271, 0.6646362098138748, 0.6657571623465212, 0.6626016260162602, 0.6591836734693878, 0.6617150573936529
# F1 leave_out_impact: 0.6616999661361328, 0.6559945504087193, 0.6632583503749148, 0.6626057529610829, 0.6630397823869432, 0.6614759647935003
#          What?   CPU Cycles     Seconds
# 0         Init     0.029072    0.029073
# 1        Setup  2294.543600  226.717683
# 2  Avg per Run     6.601318    0.103356
# 3    Total Run   660.131757   10.335632
# Changes caused by each step:
#                     Step  \
# 0  education-num_imputer
# 1   capital-gain_imputer
# 2           race_imputer
# 3    categorical_imputer
# 4      numerical_imputer
# 5       numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                      education-num
# 1                                                                                                                                                       capital-gain
# 2                                                                                                                                                               race
# 3                                                                                                                                                                  -
# 4                                                                                                                              occupation, workclass, native-country
# 5  hours-per-week, sex, workclass, capital-gain, race, native-country, age, marital-status, capital-loss, fnlwgt, occupation, relationship, education, education-num
#
#    No of rows
# 0       20825
# 1       20785
# 2       20832
# 3           0
# 4        1927
# 5       26048

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA_MIN,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.800000',
                                     dataset=EXPERIMENT_DATA_MAX,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='capital-gain_imputer',
                                         model='HGB',
                                         dataset='adult',
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset='adult', sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset='adult', sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
