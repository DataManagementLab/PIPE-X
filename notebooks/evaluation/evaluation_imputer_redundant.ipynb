# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Imputer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODELS = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

EXPERIMENT_NAME = 'sc_imputer_redundant'
EXPERIMENT_DATA_MIN = 'adult_noisy_0.000000'
EXPERIMENT_DATA_MAX = 'adult_noisy_0.800000'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_imputer_redundant.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                              experiment               dataset model  \
# 0   sc_imputer_redundant_adult_0.000000  adult_noisy_0.000000    DT
# 1   sc_imputer_redundant_adult_0.000000  adult_noisy_0.000000   GBT
# 2   sc_imputer_redundant_adult_0.000000  adult_noisy_0.000000   HGB
# 3   sc_imputer_redundant_adult_0.040000  adult_noisy_0.040000    DT
# 4   sc_imputer_redundant_adult_0.040000  adult_noisy_0.040000   GBT
# ..                                  ...                   ...   ...
# 58  sc_imputer_redundant_adult_0.760000  adult_noisy_0.760000   GBT
# 59  sc_imputer_redundant_adult_0.760000  adult_noisy_0.760000   HGB
# 60  sc_imputer_redundant_adult_0.800000  adult_noisy_0.800000    DT
# 61  sc_imputer_redundant_adult_0.800000  adult_noisy_0.800000   GBT
# 62  sc_imputer_redundant_adult_0.800000  adult_noisy_0.800000   HGB
#
#     sample_size status  \
# 0           100     OK
# 1           100     OK
# 2           100     OK
# 3           100     OK
# 4           100     OK
# ..          ...    ...
# 58          100     OK
# 59          100     OK
# 60          100     OK
# 61          100     OK
# 62          100     OK
#
#                                                                                                                                                                                                                                                                                                                                                    aggregated_impacts
# 0   {'immediate_impact': [0.030885902607440823, 0.015932200862762418, -0.005123579892059999, 0.9864533890674257, -0.00038940409501985184, -0.07009916760093571, 0.04234065905038659], 'leave_out_impact': [-0.02646700455827767, -0.03604595715674225, -0.03193256140844547, 0.9647528529935473, 0.030420532702937382, -0.043994706596789356, -0.025602093539557096]}
# 1                           {'immediate_impact': [0.2889022230126465, 0.015377424575369798, 0.015055011081702563, 0.313722929043843, -0.007327290054064334, 0.05072944339247679, 0.32354025894802557], 'leave_out_impact': [0.6206369423513, 0.5647791147153429, 0.6025055941058971, 0.7255720117782116, 0.2872960423715211, 0.6393076874326089, 0.6170244536409015]}
# 2                    {'immediate_impact': [0.1774431525183568, 0.06954370991361328, -0.025087617905037253, 0.5691364852075295, 0.01920109506650617, 0.02081240059694833, 0.16895077460208313], 'leave_out_impact': [0.1988593698045855, 0.08611504506549676, 0.10659284532395001, 0.7542342624799814, 0.16387378894851087, 0.20120999675285564, 0.16975011086263675]}
# 3                {'immediate_impact': [0.08082388192280868, 0.03381471780528987, 0.022315869422595194, 0.8440740611455876, 0.0135897991071324, -0.035075343607387115, 0.04045701420397303], 'leave_out_impact': [0.024665835268379115, 0.06566259540103889, 0.043936066715231835, 0.9887272441929518, 0.0417161106227105, 0.03909075170574608, 0.033018283294266794]}
# 4                       {'immediate_impact': [0.349357897787786, -0.03855757565271152, 0.14377469325242792, 0.25425528566106287, 0.01851496166774644, 0.054329107896336756, 0.21832562938735173], 'leave_out_impact': [0.4436764208100107, 0.6428942548791373, 0.31495371515287535, 0.671040014996678, 0.19508414924738376, 0.36251704312205874, 0.3704634213192544]}
# ..                                                                                                                                                                                                                                                                                                                                                                ...
# 58  {'immediate_impact': [0.14529859319995425, 0.9367851001875538, -0.020893690324543284, -0.04166090800906396, 0.0003554964714898928, -0.03764766588665637, 0.01776307436126598], 'leave_out_impact': [0.019861882832098072, -0.2075107611415404, 0.030723190997527062, -0.12391526317341968, 0.016701173290355618, -0.0074476068551642145, -0.0011620244375255572]}
# 59       {'immediate_impact': [-0.00968158444442122, 0.9286586283180256, -0.01284816033900497, 0.06257416317207205, -0.006932047165557782, 0.020458263319871817, 0.01777073713901483], 'leave_out_impact': [0.019320876282193353, -0.19641527386835295, 0.026984484523100188, 0.09824193766426433, 0.03839511061526904, -0.010506589149810543, 0.031025841936780752]}
# 60            {'immediate_impact': [0.0017380064992036088, 0.4880181309582981, 0.00519230392512148, 0.4576543027747878, -0.01631543522446786, 0.02205968826706986, 0.04165300279998691], 'leave_out_impact': [0.08470168049726733, 0.014834825899853212, 0.026831282589719247, 0.5386715688991024, 0.03946537695815446, 0.003513762427499572, 0.0028019182089618045]}
# 61          {'immediate_impact': [0.010420583965452345, 0.9413121166386113, -0.020340998971477307, 0.026160789008242036, 0.003646261581337338, 0.028468142208524488, 0.010333105569309877], 'leave_out_impact': [0.10115346185813037, 0.04045347554399524, 0.10977445106455466, 0.01464632385721475, 0.011950835153914104, 0.08276377167470719, 0.08714575132803346]}
# 62           {'immediate_impact': [-0.03820886442289229, 0.942957115869919, -0.004364375443744156, 0.043029708933389685, 0.00980355417024336, 0.031872032871310144, 0.014910828021774254], 'leave_out_impact': [0.02194390334321502, -0.22115953983993236, 0.04908275165388327, 0.12527818610734595, 0.05436040298342184, 0.050552651488760016, 0.07802616441229039]}
#
# [63 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA_MIN,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.800000',
                                    dataset=EXPERIMENT_DATA_MAX,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_imputer_redundant_adult_0.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_imputer/sc_imputer_redundant.pkl
#
# Sample size: 100
# Samples: [588, 726, 726, 820, 843, 911, 1020, 1080, 1954, 1966, 1966, 1966, 2573, 2620, 2620, 5014, 5463, 6184, 6243, 6243, 6243, 7703, 8376, 8771, 8923, 9089, 9535, 9971, 10246, 10739, 10889, 10889, 11268, 11953, 11953, 11989, 13003, 13814, 13814, 14164, 14369, 14847, 15275, 15275, 16445, 16445, 16783, 17351, 17351, 17603, 17615, 17832, 18664, 18825, 18825, 18999, 19146, 19835, 20045, 20045, 20286, 20343, 20411, 20533, 21231, 21727, 21841, 23291, 23291, 23332, 23586, 24161, 24267, 24373, 24373, 24407, 25040, 25357, 25462, 25488, 25488, 26366, 26775, 26775, 26985, 27537, 27633, 27633, 28023, 28023, 28315, 28333, 29521, 29670, 30129, 30950, 31309, 31585, 31990, 32534]
# Pipeline steps: education-num_imputer, capital-gain_imputer, race_encoder, race_imputer, replace_marital-status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.1774431525183568, 0.06954370991361328, -0.025087617905037253, 0.5691364852075295, 0.01920109506650617, 0.02081240059694833, 0.16895077460208313], 'leave_out_impact': [0.1988593698045855, 0.08611504506549676, 0.10659284532395001, 0.7542342624799814, 0.16387378894851087, 0.20120999675285564, 0.16975011086263675]}
# F1 immediate_impact: 0.7237843202117102, 0.7215738579526508, 0.7191531591134634, 0.721214120752227, 0.7206611570247934, 0.7214642262895175, 0.7207147584381205, 0.7242744063324539
# F1 leave_out_impact: 0.7162117724432753, 0.71875, 0.7184594953519257, 0.7252964426877471, 0.7185946304275771, 0.7177792465300727, 0.721873968987133
#          What?  CPU Cycles    Seconds
# 0         Init    0.031787   0.031788
# 1        Setup  677.442619  27.890127
# 2  Avg per Run    7.189295   0.112363
# 3    Total Run  718.929450  11.236315
# Changes caused by each step:
#                      Step  \
# 0   education-num_imputer
# 1    capital-gain_imputer
# 2            race_imputer
# 3  replace_marital-status
# 4     categorical_imputer
# 5       numerical_imputer
# 6        numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                                                                                  -
# 2                                                                                                                                                                  -
# 3                                                                                                                                                     marital-status
# 4                                                                                                                                                                  -
# 5                                                                                                                              workclass, native-country, occupation
# 6  hours-per-week, capital-loss, occupation, race, native-country, sex, education-num, relationship, age, capital-gain, workclass, marital-status, fnlwgt, education
#
#    No of rows
# 0           0
# 1           0
# 2           0
# 3       26048
# 4           0
# 5        1927
# 6       26048
# Name: sc_imputer_redundant_adult_0.800000
# Dataset: adult_noisy_0.800000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_imputer/sc_imputer_redundant.pkl
#
# Sample size: 100
# Samples: [588, 726, 726, 820, 843, 911, 1020, 1080, 1954, 1966, 1966, 1966, 2573, 2620, 2620, 5014, 5463, 6184, 6243, 6243, 6243, 7703, 8376, 8771, 8923, 9089, 9535, 9971, 10246, 10739, 10889, 10889, 11268, 11953, 11953, 11989, 13003, 13814, 13814, 14164, 14369, 14847, 15275, 15275, 16445, 16445, 16783, 17351, 17351, 17603, 17615, 17832, 18664, 18825, 18825, 18999, 19146, 19835, 20045, 20045, 20286, 20343, 20411, 20533, 21231, 21727, 21841, 23291, 23291, 23332, 23586, 24161, 24267, 24373, 24373, 24407, 25040, 25357, 25462, 25488, 25488, 26366, 26775, 26775, 26985, 27537, 27633, 27633, 28023, 28023, 28315, 28333, 29521, 29670, 30129, 30950, 31309, 31585, 31990, 32534]
# Pipeline steps: education-num_imputer, capital-gain_imputer, race_encoder, race_imputer, replace_marital-status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [-0.03820886442289229, 0.942957115869919, -0.004364375443744156, 0.043029708933389685, 0.00980355417024336, 0.031872032871310144, 0.014910828021774254], 'leave_out_impact': [0.02194390334321502, -0.22115953983993236, 0.04908275165388327, 0.12527818610734595, 0.05436040298342184, 0.050552651488760016, 0.07802616441229039]}
# F1 immediate_impact: 0.6596538853070919, 0.6648630368616841, 0.6578140960163432, 0.6626016260162602, 0.66440447913132, 0.6680203045685279, 0.6594521474467365, 0.6580116159890673
# F1 leave_out_impact: 0.6630508474576271, 0.6494915254237288, 0.6637407157326131, 0.6727028839704896, 0.664409075516424, 0.6664415935178933, 0.6635103145079473
#          What?   CPU Cycles     Seconds
# 0         Init     0.032402    0.032402
# 1        Setup  2553.773072  256.674368
# 2  Avg per Run     7.349332    0.115035
# 3    Total Run   734.933188   11.503451
# Changes caused by each step:
#                      Step  \
# 0   education-num_imputer
# 1    capital-gain_imputer
# 2            race_imputer
# 3  replace_marital-status
# 4     categorical_imputer
# 5       numerical_imputer
# 6        numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                      education-num
# 1                                                                                                                                                       capital-gain
# 2                                                                                                                                                               race
# 3                                                                                                                                                     marital-status
# 4                                                                                                                                                                  -
# 5                                                                                                                              workclass, native-country, occupation
# 6  hours-per-week, capital-loss, occupation, race, native-country, sex, education-num, relationship, age, capital-gain, workclass, marital-status, fnlwgt, education
#
#    No of rows
# 0       20825
# 1       20785
# 2       20832
# 3       26048
# 4           0
# 5        1927
# 6       26048

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA_MIN,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.800000',
                                     dataset=EXPERIMENT_DATA_MAX,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='capital-gain_imputer',
                                         model='HGB',
                                         dataset='adult',
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset='adult', sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset='adult', sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
