# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Destroyer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODEL_NAMES = [
    'LR',
    'DT',
    'GBT',
    'KNN',
    'HGB',
    'NN',
    'SVC',
]

MODELS_NAN = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

MODELS = MODELS_NAN

EXPERIMENT_NAME = 'sc_destroyer_scaled_missing'
EXPERIMENT_DATA = 'adult_noisy_0.000000'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_destroyer_scaled_missing.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                     experiment               dataset model  \
# 0   sc_destroyer_scaled_missing_adult_0.000000  adult_noisy_0.000000    DT
# 1   sc_destroyer_scaled_missing_adult_0.000000  adult_noisy_0.000000   GBT
# 2   sc_destroyer_scaled_missing_adult_0.000000  adult_noisy_0.000000   HGB
# 3   sc_destroyer_scaled_missing_adult_0.040000  adult_noisy_0.000000    DT
# 4   sc_destroyer_scaled_missing_adult_0.040000  adult_noisy_0.000000   GBT
# ..                                         ...                   ...   ...
# 73  sc_destroyer_scaled_missing_adult_0.960000  adult_noisy_0.000000   GBT
# 74  sc_destroyer_scaled_missing_adult_0.960000  adult_noisy_0.000000   HGB
# 75  sc_destroyer_scaled_missing_adult_1.000000  adult_noisy_0.000000    DT
# 76  sc_destroyer_scaled_missing_adult_1.000000  adult_noisy_0.000000   GBT
# 77  sc_destroyer_scaled_missing_adult_1.000000  adult_noisy_0.000000   HGB
#
#     sample_size status  \
# 0           100     OK
# 1           100     OK
# 2           100     OK
# 3           100     OK
# 4           100     OK
# ..          ...    ...
# 73          100     OK
# 74          100     OK
# 75          100     OK
# 76          100     OK
# 77          100     OK
#
#                                                                                                                                                                                                                                                               aggregated_impacts
# 0                {'immediate_impact': [1.0600354008461625, -0.02830126040849192, 0.01464748852658907, -0.03604400109518601, -0.01033762786907356], 'leave_out_impact': [1.1176575483913138, 0.014806660168903056, 0.09559053918814243, 0.0800366672366487, 0.07661763309216915]}
# 1                      {'immediate_impact': [0.6575504583023921, -0.03718664248275726, -0.010843536036708153, 0.08126691967362489, 0.3092128005434486], 'leave_out_impact': [0.737062926398975, 0.3048971989269928, 0.4103487101846329, 0.4226914842735073, 0.3987185418270514]}
# 2                   {'immediate_impact': [0.8362494593711197, 0.027686721129293174, 0.002675297137269278, -0.02648617799001772, 0.15987470035233559], 'leave_out_impact': [0.6387961311347486, 0.1369155573041896, 0.1556868109435845, 0.12357591968919886, 0.2470215354969655]}
# 3              {'immediate_impact': [0.9598759843644092, -0.042616997854520465, 0.13013573595341224, -0.038969917379505274, -0.008424805083795466], 'leave_out_impact': [0.7965559832778277, 0.03223805531857754, 0.1852981924702995, 0.07155570487727918, 0.10468320821165669]}
# 4                   {'immediate_impact': [0.36465014174903215, -0.013818598655278179, 0.18863850739558768, 0.20965218042604175, 0.2508777690846167], 'leave_out_impact': [0.6949367468184415, 0.24152834867607853, 0.5973388188787822, 0.48352263635280324, 0.4854556621852732]}
# ..                                                                                                                                                                                                                                                                           ...
# 73     {'immediate_impact': [-0.0434905771355988, 0.0033457618316312444, 1.0518041934459896, -0.013913380605369946, 0.002254002463347356], 'leave_out_impact': [2.376984795810228e-05, 0.0017339340856016407, 1.021783835117708, -0.0007131515628472075, -0.001047396971465068]}
# 74         {'immediate_impact': [0.014295896870113196, -0.013152577895975771, 0.9999917061901052, -0.016302436311811528, 0.015167411147568895], 'leave_out_impact': [0.008478591352023782, 0.0012715773567781414, 0.9906523403966291, 0.0274443569292451, 0.008461499154854252]}
# 75      {'immediate_impact': [0.2286609480969615, -0.010626519910424853, 0.7786195732543976, 0.0037069588493936277, -0.0003609602903281819], 'leave_out_impact': [0.23739354127792311, 0.0029424651446175103, 0.794181148183119, -0.009709598086016402, -0.0049034621913156134]}
# 76  {'immediate_impact': [-0.041746188212599164, 0.003322601465319513, 1.0388947297351891, -0.0036979239914713595, 0.0032267810035621286], 'leave_out_impact': [-0.007360650758077818, 0.0013398998408521061, 1.020747821183529, 0.0005104651130259447, 0.00044602425395292374]}
# 77        {'immediate_impact': [0.014213662759672783, -0.012666300347293815, 1.0019451499871255, -0.011685034520871091, 0.008192522121366565], 'leave_out_impact': [0.005499993874909566, 0.006325595215119232, 0.9904836469070832, 0.006242665797315029, 0.011616765993165292]}
#
# [78 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_destroyer_scaled_missing_adult_0.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_scaled_missing_0.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2345, 2392, 2593, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4381, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 9649, 10344, 10513, 10610, 10899, 12902, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19845, 20744, 20822, 21343, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, destroyer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.8362494593711197, 0.027686721129293174, 0.002675297137269278, -0.02648617799001772, 0.15987470035233559], 'leave_out_impact': [0.6387961311347486, 0.1369155573041896, 0.1556868109435845, 0.12357591968919886, 0.2470215354969655]}
# F1 immediate_impact: 0.7213223140495868, 0.7201591511936339, 0.7113470471134705, 0.714190093708166, 0.7168934616661136, 0.7161226508407518
# F1 leave_out_impact: 0.719762062128222, 0.7151394422310757, 0.7198675496688741, 0.7189973614775725, 0.7222405271828666
#          What?  CPU Cycles    Seconds
# 0         Init    0.023567   0.023568
# 1        Setup  497.323714  20.792383
# 2  Avg per Run    5.242918   0.081952
# 3    Total Run  524.291789   8.195220
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2               destroyer
# 3       numerical_imputer
# 4        numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                                                                                  -
# 3                                                                                                                              occupation, workclass, native-country
# 4  fnlwgt, education-num, education, race, capital-loss, occupation, hours-per-week, age, workclass, sex, native-country, relationship, marital-status, capital-gain
#
#    No of rows
# 0       26048
# 1           0
# 2           0
# 3        1927
# 4       26048
# Name: sc_destroyer_scaled_missing_adult_1.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_scaled_missing_1.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2345, 2392, 2593, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4381, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 9649, 10344, 10513, 10610, 10899, 12902, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19845, 20744, 20822, 21343, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, destroyer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.014213662759672783, -0.012666300347293815, 1.0019451499871255, -0.011685034520871091, 0.008192522121366565], 'leave_out_impact': [0.005499993874909566, 0.006325595215119232, 0.9904836469070832, 0.006242665797315029, 0.011616765993165292]}
# F1 immediate_impact: 0.7213223140495868, 0.7201591511936339, 0.7113470471134705, 0.6212590299277606, 0.6208810267082899, 0.6219130434782608
# F1 leave_out_impact: 0.6229281767955801, 0.6162911611785096, 0.7198675496688741, 0.6273291925465838, 0.6170952050034746
#          What?  CPU Cycles    Seconds
# 0         Init    0.023530   0.023531
# 1        Setup  490.229452  20.689776
# 2  Avg per Run    5.058714   0.079074
# 3    Total Run  505.871387   7.907353
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2               destroyer
# 3       numerical_imputer
# 4        numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                              education-num, hours-per-week, age, sex, capital-gain
# 3                                                                                                                              occupation, workclass, native-country
# 4  fnlwgt, education-num, education, race, capital-loss, occupation, hours-per-week, age, workclass, sex, native-country, relationship, marital-status, capital-gain
#
#    No of rows
# 0       26048
# 1           0
# 2       26048
# 3        1927
# 4       26048

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='destroyer',
                                         model='HGB',
                                         dataset=EXPERIMENT_DATA,
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
