# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Destroyer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODEL_NAMES = [
    'LR',
    'DT',
    'GBT',
    'KNN',
    'HGB',
    'NN',
    'SVC',
]

MODELS_NAN = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

MODELS = MODEL_NAMES

EXPERIMENT_NAME = 'sc_destroyer_unscaled'
EXPERIMENT_DATA = 'adult'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_destroyer_unscaled.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                experiment dataset model  sample_size status  \
# 0    sc_destroyer_unscaled_adult_0.000000   adult    LR          100     OK
# 1    sc_destroyer_unscaled_adult_0.000000   adult    DT          100     OK
# 2    sc_destroyer_unscaled_adult_0.000000   adult   GBT          100     OK
# 3    sc_destroyer_unscaled_adult_0.000000   adult   KNN          100     OK
# 4    sc_destroyer_unscaled_adult_0.000000   adult   HGB          100     OK
# ..                                    ...     ...   ...          ...    ...
# 177  sc_destroyer_unscaled_adult_1.000000   adult   GBT          100     OK
# 178  sc_destroyer_unscaled_adult_1.000000   adult   KNN          100     OK
# 179  sc_destroyer_unscaled_adult_1.000000   adult   HGB          100     OK
# 180  sc_destroyer_unscaled_adult_1.000000   adult    NN          100     OK
# 181  sc_destroyer_unscaled_adult_1.000000   adult   SVC          100     OK
#
#                                                                                                                                                                                                                                                               aggregated_impacts
# 0        {'immediate_impact': [-0.01546525914050311, -0.002436431530072813, 0.0009267221009989564, 1.0136511684150837, 0.0033238001544932593], 'leave_out_impact': [0.3755236851233292, 0.0016759449099944426, 0.0056447918618624995, 1.0175934621772442, 0.004847138252191832]}
# 1                  {'immediate_impact': [0.7534768194632231, 0.01624514904185849, 0.2132234637357471, -0.041982280655302906, 0.05903684841447447], 'leave_out_impact': [0.9730971872190628, 0.04927554504175112, 0.22322902942103562, 0.22870367437014566, 0.22854109655001623]}
# 2              {'immediate_impact': [0.6962300287750106, 0.011396934865139341, 0.0004731689730851088, -0.040203986304847145, 0.33210385369161166], 'leave_out_impact': [0.7057545293351442, 0.32727126016202157, 0.28787636892412616, 0.31974870771827485, 0.31674183902098973]}
# 3         {'immediate_impact': [0.010623526572869236, 0.0031252817317670347, -0.0012967836730587434, 0.9798236239709194, 0.007724351397503538], 'leave_out_impact': [0.05099658605770055, 0.007500100729357872, 0.005957483193118265, 0.9914586265766896, 0.004906854702472859]}
# 4             {'immediate_impact': [0.8792327966752977, 0.0015731007943196236, -0.051484583884361716, -0.03282980549421168, 0.20350849190895623], 'leave_out_impact': [0.7857383768040173, 0.06631911528732819, 0.24474737083276848, 0.047709606182720236, 0.23199045065397733]}
# ..                                                                                                                                                                                                                                                                           ...
# 177  {'immediate_impact': [0.007498597547344483, 0.00483754420709437, -0.00021095658865231078, -0.0046107761222000465, 0.9924855909564131], 'leave_out_impact': [0.007918373575621423, 0.0032977502672093878, 0.0036972758952361685, 0.0038725226170239573, 0.9933307183048063]}
# 178          {'immediate_impact': [0.004900360507912375, 0.0014781461240343501, 0.00020852767444173528, 0.5872454588902717, 0.40616750680334], 'leave_out_impact': [0.038294941753570164, 0.0010222745569169005, 0.0010795404823869493, 0.1868454809448823, 0.4035464209773087]}
# 179     {'immediate_impact': [0.02086149898837323, -0.007474214018795184, 0.006776606248663025, -0.019635462530579663, 0.9994715713123381], 'leave_out_impact': [0.019169316827286058, -0.0012174414188012039, 0.006310379536329621, 0.0019398649295797171, 0.9799461396219393]}
# 180             {'immediate_impact': [0.04112135187730192, 0.001439881451126394, -0.012256180551986033, 0.37307684313041234, 0.596618104093145], 'leave_out_impact': [-0.18992579849677382, -0.17223055475039978, -0.1449403253572955, 0.22177171689940678, 0.5172553605314139]}
# 181        {'immediate_impact': [0.01376178297227519, -0.004082004673011503, -0.0006077352092571736, 0.37147140737040824, 0.6194565495395851], 'leave_out_impact': [-0.013509115027673038, 0.0019332839208952496, 0.001800139152088201, 0.11935817707902792, 0.617700823314646]}
#
# [182 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_destroyer_unscaled_adult_0.000000
# Dataset: adult
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_0.000000.pkl
#
# Sample size: 100
# Samples: [200, 414, 480, 1080, 1303, 2000, 2046, 2252, 3352, 3663, 3967, 4099, 4381, 4573, 4662, 5165, 5261, 5421, 5595, 5975, 6142, 6392, 6743, 6847, 6871, 7132, 7225, 7289, 8180, 8204, 8292, 8758, 9341, 9522, 9797, 10047, 10178, 10500, 10694, 10899, 11479, 11509, 11597, 12010, 12764, 13048, 13353, 14043, 14166, 14425, 14620, 14943, 14967, 15031, 15325, 15923, 16139, 16240, 16354, 16723, 17189, 18227, 18552, 18633, 18640, 20293, 21048, 21186, 21343, 21352, 21544, 21614, 22493, 22808, 22956, 22997, 23291, 23582, 23617, 24440, 24518, 24591, 25327, 25572, 25648, 25741, 25832, 25956, 26016, 26431, 26480, 27137, 27558, 27798, 27981, 28443, 28935, 29032, 29317, 30158]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.8792327966752977, 0.0015731007943196236, -0.051484583884361716, -0.03282980549421168, 0.20350849190895623], 'leave_out_impact': [0.7857383768040173, 0.06631911528732819, 0.24474737083276848, 0.047709606182720236, 0.23199045065397733]}
# F1 immediate_impact: 0.720456979650125, 0.713150289017341, 0.7116920842411039, 0.720855614973262, 0.714954954954955, 0.7133574007220217
# F1 leave_out_impact: 0.714744734023563, 0.7198275862068966, 0.7173208498379546, 0.7158273381294964, 0.716375312165537
#          What?  CPU Cycles   Seconds
# 0         Init    0.021074  0.021074
# 1        Setup  349.966385  6.031191
# 2  Avg per Run    5.684008  0.088845
# 3    Total Run  568.400845  8.884494
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2       numerical_imputer
# 3        numerical_scaler
# 4               destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                                                                                  -
# 3  fnlwgt, hours-per-week, education, age, capital-gain, native-country, workclass, occupation, relationship, race, capital-loss, sex, education-num, marital-status
# 4                                                                                                                                                                  -
#
#    No of rows
# 0       24129
# 1           0
# 2           0
# 3       24129
# 4           0
# Name: sc_destroyer_unscaled_adult_1.000000
# Dataset: adult
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_1.000000.pkl
#
# Sample size: 100
# Samples: [200, 414, 480, 1080, 1303, 2000, 2046, 2252, 3352, 3663, 3967, 4099, 4381, 4573, 4662, 5165, 5261, 5421, 5595, 5975, 6142, 6392, 6743, 6847, 6871, 7132, 7225, 7289, 8180, 8204, 8292, 8758, 9341, 9522, 9797, 10047, 10178, 10500, 10694, 10899, 11479, 11509, 11597, 12010, 12764, 13048, 13353, 14043, 14166, 14425, 14620, 14943, 14967, 15031, 15325, 15923, 16139, 16240, 16354, 16723, 17189, 18227, 18552, 18633, 18640, 20293, 21048, 21186, 21343, 21352, 21544, 21614, 22493, 22808, 22956, 22997, 23291, 23582, 23617, 24440, 24518, 24591, 25327, 25572, 25648, 25741, 25832, 25956, 26016, 26431, 26480, 27137, 27558, 27798, 27981, 28443, 28935, 29032, 29317, 30158]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.02086149898837323, -0.007474214018795184, 0.006776606248663025, -0.019635462530579663, 0.9994715713123381], 'leave_out_impact': [0.019169316827286058, -0.0012174414188012039, 0.006310379536329621, 0.0019398649295797171, 0.9799461396219393]}
# F1 immediate_impact: 0.720456979650125, 0.713150289017341, 0.7116920842411039, 0.720855614973262, 0.714954954954955, 0.6383136094674556
# F1 leave_out_impact: 0.6410066617320503, 0.6264518546272012, 0.6405563689604685, 0.6317365269461078, 0.716375312165537
#          What?  CPU Cycles   Seconds
# 0         Init    0.022289  0.022289
# 1        Setup  328.282579  5.659506
# 2  Avg per Run    5.214580  0.081515
# 3    Total Run  521.458035  8.151456
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2       numerical_imputer
# 3        numerical_scaler
# 4               destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                                                                                  -
# 3  fnlwgt, hours-per-week, education, age, capital-gain, native-country, workclass, occupation, relationship, race, capital-loss, sex, education-num, marital-status
# 4                                                                                                              hours-per-week, age, capital-gain, sex, education-num
#
#    No of rows
# 0       24129
# 1           0
# 2           0
# 3       24129
# 4       24129

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='destroyer',
                                         model='HGB',
                                         dataset=EXPERIMENT_DATA,
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: LR, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: KNN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: NN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: SVC, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: LR, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: KNN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: NN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: SVC, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
