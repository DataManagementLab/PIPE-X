# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Destroyer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODEL_NAMES = [
    'LR',
    'DT',
    'GBT',
    'KNN',
    'HGB',
    'NN',
    'SVC',
]

MODELS_NAN = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

MODELS = MODELS_NAN

EXPERIMENT_NAME = 'sc_destroyer_scaled_minimal_missing'
EXPERIMENT_DATA = 'adult_noisy_0.000000'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_destroyer_scaled_minimal_missing.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                             experiment               dataset  \
# 0   sc_destroyer_scaled_minimal_missing_adult_0.000000  adult_noisy_0.000000
# 1   sc_destroyer_scaled_minimal_missing_adult_0.000000  adult_noisy_0.000000
# 2   sc_destroyer_scaled_minimal_missing_adult_0.000000  adult_noisy_0.000000
# 3   sc_destroyer_scaled_minimal_missing_adult_0.040000  adult_noisy_0.000000
# 4   sc_destroyer_scaled_minimal_missing_adult_0.040000  adult_noisy_0.000000
# ..                                                 ...                   ...
# 73  sc_destroyer_scaled_minimal_missing_adult_0.960000  adult_noisy_0.000000
# 74  sc_destroyer_scaled_minimal_missing_adult_0.960000  adult_noisy_0.000000
# 75  sc_destroyer_scaled_minimal_missing_adult_1.000000  adult_noisy_0.000000
# 76  sc_destroyer_scaled_minimal_missing_adult_1.000000  adult_noisy_0.000000
# 77  sc_destroyer_scaled_minimal_missing_adult_1.000000  adult_noisy_0.000000
#
#    model  sample_size status  \
# 0     DT          100     OK
# 1    GBT          100     OK
# 2    HGB          100     OK
# 3     DT          100     OK
# 4    GBT          100     OK
# ..   ...          ...    ...
# 73   GBT          100     OK
# 74   HGB          100     OK
# 75    DT          100     OK
# 76   GBT          100     OK
# 77   HGB          100     OK
#
#                                                                                                                                                                                                                aggregated_impacts
# 0                {'immediate_impact': [0.4813082706151735, -0.06476141907445074, 0.24332835573679265, 0.34012479272248447], 'leave_out_impact': [0.4020927440197893, 0.5295681637483308, 0.5107249848362294, 0.5173272173204566]}
# 1                {'immediate_impact': [0.4062200652400608, -0.0031592981040999214, 0.23811148365549145, 0.35882774920854776], 'leave_out_impact': [0.37330692972802576, 0.5712924453702817, 0.5606051662435, 0.5806141962942629]}
# 2               {'immediate_impact': [0.6223881401457959, -0.11855190687255365, -0.026090038004164304, 0.5222538047309221], 'leave_out_impact': [0.5553115456433134, 0.5250579677854136, 0.5359025126907353, 0.4771396166479036]}
# 3             {'immediate_impact': [0.20520451517636495, 0.6576977859427338, -0.04038454806288717, 0.17748224694378872], 'leave_out_impact': [0.1128160277162598, 0.7330491607941227, 0.08765351631854872, 0.060382829863612535]}
# 4               {'immediate_impact': [0.23987487271025376, 0.38159194667776136, 0.1623870348417754, 0.21614614577020932], 'leave_out_impact': [0.2264441471970703, 0.7369913317504551, 0.33272070794805875, 0.33055641414183135]}
# ..                                                                                                                                                                                                                            ...
# 73     {'immediate_impact': [0.0015927522095783397, 0.986545861025719, 0.010695646964706738, 0.001165739799996018], 'leave_out_impact': [-0.00037858637889446315, 0.9955696587699482, 0.019926116138868518, 0.01928908856685041]}
# 74   {'immediate_impact': [0.0037193222390975982, 1.0002116651698338, -0.006194396784795669, 0.0022634093758639876], 'leave_out_impact': [0.010246281262933168, 0.9778535362956963, -0.000638358097373227, 0.030026449690875485]}
# 75         {'immediate_impact': [0.029498242722228472, 0.9554140228036279, 0.01314872719950187, 0.0019390072746420586], 'leave_out_impact': [0.0099553719139279, 0.9364686023125951, 0.006834471460298934, 0.009040832473597259]}
# 76  {'immediate_impact': [0.0016041885452394667, 1.0002740791272402, -0.003737630886311827, 0.001859363213831926], 'leave_out_impact': [0.0004490110073380891, 0.9944805617103795, -0.008743487779123732, -0.010184846872801379]}
# 77     {'immediate_impact': [0.004775438822093457, 0.9976600019566776, -0.0057472486267427, 0.0033118078479713107], 'leave_out_impact': [0.006908298540464232, 0.9785304160079125, -0.001254709432548717, 0.0007050694222747528]}
#
# [78 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_destroyer_scaled_minimal_missing_adult_0.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_scaled_minimal_missing_0.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2392, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 8604, 9649, 10344, 10513, 10610, 10899, 12788, 12902, 12920, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19182, 19845, 20744, 20822, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: categorical_encoder, categorical_imputer, destroyer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.6223881401457959, -0.11855190687255365, -0.026090038004164304, 0.5222538047309221], 'leave_out_impact': [0.5553115456433134, 0.5250579677854136, 0.5359025126907353, 0.4771396166479036]}
# F1 immediate_impact: 0.712720026569246, 0.7213223140495868, 0.7175925925925926, 0.7204763479986768, 0.7184401850627892
# F1 leave_out_impact: 0.7156084656084656, 0.7186666666666667, 0.7156634519454605, 0.7220383851753805
#          What?  CPU Cycles    Seconds
# 0         Init    0.022463   0.022463
# 1        Setup  421.555889  17.487591
# 2  Avg per Run    4.320995   0.067547
# 3    Total Run  432.099483   6.754666
# Changes caused by each step:
#                   Step  \
# 0  categorical_imputer
# 1            destroyer
# 2    numerical_imputer
# 3     numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                                                                                  -
# 2                                                                                                                              native-country, workclass, occupation
# 3  native-country, workclass, capital-gain, education-num, occupation, age, capital-loss, relationship, hours-per-week, marital-status, education, sex, race, fnlwgt
#
#    No of rows
# 0           0
# 1           0
# 2        1927
# 3       26048
# Name: sc_destroyer_scaled_minimal_missing_adult_1.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_scaled_minimal_missing_1.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2392, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 8604, 9649, 10344, 10513, 10610, 10899, 12788, 12902, 12920, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19182, 19845, 20744, 20822, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: categorical_encoder, categorical_imputer, destroyer, numerical_imputer, numerical_scaler
#
# Aggregated impacts: {'immediate_impact': [0.004775438822093457, 0.9976600019566776, -0.0057472486267427, 0.0033118078479713107], 'leave_out_impact': [0.006908298540464232, 0.9785304160079125, -0.001254709432548717, 0.0007050694222747528]}
# F1 immediate_impact: 0.712720026569246, 0.7213223140495868, 0.6219130434782608, 0.6155454862321367, 0.6167768882701009
# F1 leave_out_impact: 0.6193103448275862, 0.7186666666666667, 0.6159722222222223, 0.6180048661800487
#          What?  CPU Cycles    Seconds
# 0         Init    0.020082   0.020083
# 1        Setup  389.482864  17.025446
# 2  Avg per Run    4.195866   0.065600
# 3    Total Run  419.586594   6.560004
# Changes caused by each step:
#                   Step  \
# 0  categorical_imputer
# 1            destroyer
# 2    numerical_imputer
# 3     numerical_scaler
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                              capital-gain, education-num, age, hours-per-week, sex
# 2                                                                                                                              native-country, workclass, occupation
# 3  native-country, workclass, capital-gain, education-num, occupation, age, capital-loss, relationship, hours-per-week, marital-status, education, sex, race, fnlwgt
#
#    No of rows
# 0           0
# 1       26048
# 2        1927
# 3       26048

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='destroyer',
                                         model='HGB',
                                         dataset=EXPERIMENT_DATA,
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
