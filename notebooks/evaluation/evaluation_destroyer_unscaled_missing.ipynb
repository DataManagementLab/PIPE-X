# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Destroyer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODEL_NAMES = [
    'LR',
    'DT',
    'GBT',
    'KNN',
    'HGB',
    'NN',
    'SVC',
]

MODELS_NAN = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

MODELS = MODELS_NAN

EXPERIMENT_NAME = 'sc_destroyer_unscaled_missing'
EXPERIMENT_DATA = 'adult_noisy_0.000000'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_destroyer_unscaled_missing.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                       experiment               dataset model  \
# 0   sc_destroyer_unscaled_missing_adult_0.000000  adult_noisy_0.000000    DT
# 1   sc_destroyer_unscaled_missing_adult_0.000000  adult_noisy_0.000000   GBT
# 2   sc_destroyer_unscaled_missing_adult_0.000000  adult_noisy_0.000000   HGB
# 3   sc_destroyer_unscaled_missing_adult_0.040000  adult_noisy_0.000000    DT
# 4   sc_destroyer_unscaled_missing_adult_0.040000  adult_noisy_0.000000   GBT
# ..                                           ...                   ...   ...
# 73  sc_destroyer_unscaled_missing_adult_0.960000  adult_noisy_0.000000   GBT
# 74  sc_destroyer_unscaled_missing_adult_0.960000  adult_noisy_0.000000   HGB
# 75  sc_destroyer_unscaled_missing_adult_1.000000  adult_noisy_0.000000    DT
# 76  sc_destroyer_unscaled_missing_adult_1.000000  adult_noisy_0.000000   GBT
# 77  sc_destroyer_unscaled_missing_adult_1.000000  adult_noisy_0.000000   HGB
#
#     sample_size status  \
# 0           100     OK
# 1           100     OK
# 2           100     OK
# 3           100     OK
# 4           100     OK
# ..          ...    ...
# 73          100     OK
# 74          100     OK
# 75          100     OK
# 76          100     OK
# 77          100     OK
#
#                                                                                                                                                                                                                                                             aggregated_impacts
# 0            {'immediate_impact': [1.0600354008461625, -0.02830126040849192, -0.05225377003297686, 0.030857257464379884, -0.010337627869073551], 'leave_out_impact': [1.1176575483913138, 0.014806660168903056, 0.09559053918814243, 0.08003666723664873, 0.0766176330921692]}
# 1                   {'immediate_impact': [0.6575504583023921, -0.03718664248275726, 0.06311311965689492, 0.007308478144540875, 0.3092145863789295], 'leave_out_impact': [0.737062926398975, 0.3048971989269928, 0.4103487101846329, 0.42269149301827325, 0.39871788329958396]}
# 2                   {'immediate_impact': [0.8362494593711197, 0.027686721129293174, -0.2194532448586578, 0.19564236400590942, 0.15987470035233556], 'leave_out_impact': [0.6387961311347486, 0.1369155573041896, 0.1556868109435845, 0.1235759196891988, 0.24702153549696554]}
# 3             {'immediate_impact': [1.065858617145028, -0.03454127455519562, -0.06318601068132974, 0.03418770716798069, -0.0023190390764830575], 'leave_out_impact': [0.7583818411149679, 0.05548144953383694, 0.07144618962099149, 0.03150241813435634, 0.08234918208236756]}
# 4               {'immediate_impact': [-0.06587070799726591, 0.030326900108509865, -0.06643511017364927, -0.02577986726401232, 1.1277587853264175], 'leave_out_impact': [0.3901787029071477, 0.10890684460620757, 0.21816637608522094, 0.7680894260335124, 0.9648346874721636]}
# ..                                                                                                                                                                                                                                                                         ...
# 73     {'immediate_impact': [-0.03947098129738577, 0.003078402373742205, -0.011889293621736373, -0.0024494200769249706, 1.050731292622305], 'leave_out_impact': [0.02896070853473184, 5.6985029726941555e-05, -0.006112495171298931, 0.09309344674544714, 1.0255077523951057]}
# 74      {'immediate_impact': [0.015685905141170776, -0.01291419954680858, -0.0022330307455943406, -0.00973541854962089, 1.009196743700853], 'leave_out_impact': [0.007974394309611499, 0.0030645052616983127, 0.008704671895627139, 0.030528170726243364, 0.9975899736750106]}
# 75         {'immediate_impact': [0.23342187152110852, -0.009718614894518252, -0.042184507913329956, 0.009282345822427226, 0.8091989054643123], 'leave_out_impact': [0.282356031209288, 0.0019129498983655152, 0.000989669027102431, 0.011376005348717085, 0.7864656036821657]}
# 76  {'immediate_impact': [-0.04161251264915174, 0.003164818371566291, -0.010544887357748532, -0.002889970062039084, 1.051882551697373], 'leave_out_impact': [-0.007703787224549986, 0.0022338940741436224, -0.0053072367028564734, -0.005741086715781385, 1.0278784900173108]}
# 77     {'immediate_impact': [0.014721974627139029, -0.012846848265317685, -0.001983893103076815, -0.010320007671655827, 1.010428774412911], 'leave_out_impact': [0.010878214449431383, 0.0023252308435090237, 0.010921661054628329, 0.009799046223908214, 0.9984655214428197]}
#
# [78 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_destroyer_unscaled_missing_adult_0.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_missing_0.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2345, 2392, 2593, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4381, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 9649, 10344, 10513, 10610, 10899, 12902, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19845, 20744, 20822, 21343, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.8362494593711197, 0.027686721129293174, -0.2194532448586578, 0.19564236400590942, 0.15987470035233556], 'leave_out_impact': [0.6387961311347486, 0.1369155573041896, 0.1556868109435845, 0.1235759196891988, 0.24702153549696554]}
# F1 immediate_impact: 0.7213223140495868, 0.7201591511936339, 0.7113470471134705, 0.7178299702282501, 0.7168934616661136, 0.7161226508407518
# F1 leave_out_impact: 0.719762062128222, 0.7151394422310757, 0.7198675496688741, 0.7189973614775725, 0.7222405271828666
#          What?  CPU Cycles    Seconds
# 0         Init    0.023683   0.023685
# 1        Setup  514.663962  21.054422
# 2  Avg per Run    5.737669   0.089767
# 3    Total Run  573.766917   8.976691
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2       numerical_imputer
# 3        numerical_scaler
# 4               destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                                              occupation, native-country, workclass
# 3  hours-per-week, marital-status, capital-gain, race, relationship, sex, capital-loss, education, age, education-num, native-country, workclass, occupation, fnlwgt
# 4                                                                                                                                                                  -
#
#    No of rows
# 0       26048
# 1           0
# 2        1927
# 3       26048
# 4           0
# Name: sc_destroyer_unscaled_missing_adult_1.000000
# Dataset: adult_noisy_0.000000
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_missing_1.000000.pkl
#
# Sample size: 100
# Samples: [690, 971, 1176, 1303, 1520, 2000, 2345, 2392, 2593, 2623, 2699, 2907, 3106, 3114, 3412, 3738, 4102, 4254, 4381, 4735, 4808, 5102, 5530, 5564, 5640, 5831, 7776, 7976, 7991, 8067, 8503, 9649, 10344, 10513, 10610, 10899, 12902, 13125, 13173, 13374, 14073, 14439, 14508, 14599, 14620, 15232, 15556, 15557, 15585, 15836, 16056, 16258, 16353, 17164, 17745, 17847, 17944, 18258, 18462, 18613, 18802, 18939, 19845, 20744, 20822, 21343, 21652, 22210, 22243, 22946, 23572, 23633, 23659, 23698, 23932, 24118, 24139, 24263, 24329, 24483, 24865, 25696, 26278, 26504, 26564, 27644, 28261, 28676, 29341, 29516, 30370, 30502, 30661, 30751, 30767, 31337, 31946, 32260, 32439, 32465]
# Pipeline steps: replace_marital_status, categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.014721974627139029, -0.012846848265317685, -0.001983893103076815, -0.010320007671655827, 1.010428774412911], 'leave_out_impact': [0.010878214449431383, 0.0023252308435090237, 0.010921661054628329, 0.009799046223908214, 0.9984655214428197]}
# F1 immediate_impact: 0.7213223140495868, 0.7201591511936339, 0.7113470471134705, 0.7178299702282501, 0.7168934616661136, 0.6242214532871972
# F1 leave_out_impact: 0.6229281767955801, 0.6190641247833623, 0.6200753682768071, 0.6273291925465838, 0.7222405271828666
#          What?  CPU Cycles    Seconds
# 0         Init    0.023684   0.023685
# 1        Setup  500.853650  20.828579
# 2  Avg per Run    5.635643   0.088156
# 3    Total Run  563.564299   8.815632
# Changes caused by each step:
#                      Step  \
# 0  replace_marital_status
# 1     categorical_imputer
# 2       numerical_imputer
# 3        numerical_scaler
# 4               destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                     marital-status
# 1                                                                                                                                                                  -
# 2                                                                                                                              occupation, native-country, workclass
# 3  hours-per-week, marital-status, capital-gain, race, relationship, sex, capital-loss, education, age, education-num, native-country, workclass, occupation, fnlwgt
# 4                                                                                                              hours-per-week, capital-gain, sex, age, education-num
#
#    No of rows
# 0       26048
# 1           0
# 2        1927
# 3       26048
# 4       26048

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='destroyer',
                                         model='HGB',
                                         dataset=EXPERIMENT_DATA,
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: DT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult_noisy_0.000000, Sample Size: 100, Experiment: None, Param: 0.0-1
