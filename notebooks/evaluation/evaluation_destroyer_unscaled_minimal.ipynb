# %% [markdown]
# # XAI for Preprocessing
# ## Evaluation Destroyer Experiments

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Base path (usually the home directory of the project)
BASE_PATH = '../..'

MODEL_NAMES = [
    'LR',
    'DT',
    'GBT',
    'KNN',
    'HGB',
    'NN',
    'SVC',
]

MODELS_NAN = [  # models able to handle NaN
    'DT',
    'GBT',
    'HGB'
]

MODELS = MODEL_NAMES

EXPERIMENT_NAME = 'sc_destroyer_unscaled_minimal'
EXPERIMENT_DATA = 'adult'

# Experiment configuration to use (relative to base path)
EXPERIMENT_CONFIG = f'experiments/yaml_files/exp_{EXPERIMENT_NAME}.yaml'

# Folder containing experiment results (relative to base path)
RESULT_PATH = 'experiments'

# Default sample size
DEFAULT_SAMPLE_SIZE = 100

# Disable displaying detail tables
SHOW_DETAIL_TABLES = False

# %%
from PIPE_X.analyzer import Analyzer

# %%
analyzer = Analyzer(BASE_PATH, EXPERIMENT_CONFIG, RESULT_PATH)
# Out:
# Loaded experiments/yaml_files/exp_sc_destroyer_unscaled_minimal.yaml
# Measures: immediate_impact, leave_out_impact

# %%
analyzer.load_results()
analyzer.display_results()
# Out:
#                                        experiment dataset model  sample_size  \
# 0    sc_destroyer_unscaled_minimal_adult_0.000000   adult    LR          100
# 1    sc_destroyer_unscaled_minimal_adult_0.000000   adult    DT          100
# 2    sc_destroyer_unscaled_minimal_adult_0.000000   adult   GBT          100
# 3    sc_destroyer_unscaled_minimal_adult_0.000000   adult   KNN          100
# 4    sc_destroyer_unscaled_minimal_adult_0.000000   adult   HGB          100
# ..                                            ...     ...   ...          ...
# 177  sc_destroyer_unscaled_minimal_adult_1.000000   adult   GBT          100
# 178  sc_destroyer_unscaled_minimal_adult_1.000000   adult   KNN          100
# 179  sc_destroyer_unscaled_minimal_adult_1.000000   adult   HGB          100
# 180  sc_destroyer_unscaled_minimal_adult_1.000000   adult    NN          100
# 181  sc_destroyer_unscaled_minimal_adult_1.000000   adult   SVC          100
#
#     status  \
# 0       OK
# 1       OK
# 2       OK
# 3       OK
# 4       OK
# ..     ...
# 177     OK
# 178     OK
# 179     OK
# 180     OK
# 181     OK
#
#                                                                                                                                                                                                                 aggregated_impacts
# 0      {'immediate_impact': [0.003502661072866403, -0.0016357909024666702, 0.9967476537626684, 0.0013854760669323718], 'leave_out_impact': [0.002136732055160975, 0.001785946979165928, 0.9974536819141453, 0.002895825485283453]}
# 1                  {'immediate_impact': [0.5290405504939081, -0.03243952346428345, -0.028922303730714645, 0.53232127670109], 'leave_out_impact': [0.5625227014214357, 0.5073598630516656, 0.5280116990767927, 0.5587062923352363]}
# 2               {'immediate_impact': [0.5267315371052639, 0.012681565196444991, -0.008101426723866484, 0.46868832442215747], 'leave_out_impact': [0.5119641545741435, 0.4728465543116883, 0.470663031851954, 0.46399727832034626]}
# 3    {'immediate_impact': [0.012404075429903079, 0.0019775626173994467, 0.9863894345309879, -0.0007710725782897556], 'leave_out_impact': [0.003233334653781287, 0.0009375132712878834, 0.9910030250085019, 0.0019361654068198169]}
# 4                     {'immediate_impact': [0.6438899146181497, -0.0693457900366555, -0.1257302033949239, 0.5511860788134298], 'leave_out_impact': [0.525493202201646, 0.470099924325811, 0.5628927045196189, 0.3126149871136406]}
# ..                                                                                                                                                                                                                             ...
# 177    {'immediate_impact': [0.0034423132510809262, 0.001989341771403523, -0.0028736605203403304, 0.9974420054978559], 'leave_out_impact': [0.002446183049862207, 0.00299956837438578, 0.0015670744403961515, 0.9946097345807917]}
# 178            {'immediate_impact': [0.006037592399247433, 0.0005485170626310656, 0.5770392733744114, 0.41637461716371], 'leave_out_impact': [0.004427247424170891, 0.00372722607322224, 0.1471766459446468, 0.41626230867449626]}
# 179     {'immediate_impact': [0.0023096345127463524, 0.003697789384448768, -0.001434201381495791, 0.9954267774843008], 'leave_out_impact': [0.004867592743071914, 0.014615755848485578, 0.004788231109480801, 0.9839870799240278]}
# 180            {'immediate_impact': [-0.07933351269527048, 0.03479475003965739, 0.28476108354362045, 0.7597776791119931], 'leave_out_impact': [0.06668483106551008, 0.12035187635688921, 0.33880196902857646, 0.7768072508185826]}
# 181     {'immediate_impact': [0.013768278314376846, -0.011205575655746364, 0.34804466138791434, 0.6493926359534551], 'leave_out_impact': [0.0032914667847120747, 0.00026224803877321936, 0.15777590045448053, 0.6509206720329757]}
#
# [182 rows x 6 columns]

# %%
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
analyzer.display_experiment_details(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                    dataset=EXPERIMENT_DATA,
                                    model='HGB',
                                    sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Name: sc_destroyer_unscaled_minimal_adult_0.000000
# Dataset: adult
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_minimal_0.000000.pkl
#
# Sample size: 100
# Samples: [200, 414, 480, 1080, 1303, 2000, 2046, 2252, 2462, 3352, 3663, 3967, 4099, 4573, 4662, 5165, 5261, 5421, 5595, 5975, 6142, 6392, 6743, 6847, 6871, 7132, 7225, 7289, 8180, 8204, 8292, 8758, 9341, 9522, 10047, 10178, 10500, 10694, 10899, 11479, 11509, 11597, 12010, 12764, 13048, 13353, 14043, 14166, 14425, 14620, 14943, 14967, 15031, 15923, 16139, 16240, 16354, 16723, 17189, 18227, 18552, 18633, 18640, 18897, 20280, 20293, 20945, 21048, 21186, 21343, 21352, 21544, 21614, 22493, 22808, 22956, 22997, 23291, 23582, 23617, 24440, 24518, 24591, 25327, 25572, 25648, 25741, 25832, 25956, 26016, 26431, 26480, 27137, 27558, 27798, 27981, 28443, 29032, 29317, 30158]
# Pipeline steps: categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.6438899146181497, -0.0693457900366555, -0.1257302033949239, 0.5511860788134298], 'leave_out_impact': [0.525493202201646, 0.470099924325811, 0.5628927045196189, 0.3126149871136406]}
# F1 immediate_impact: 0.7133666904932094, 0.720456979650125, 0.7064784654361201, 0.7085137085137085, 0.7148451406194375
# F1 leave_out_impact: 0.714744734023563, 0.7135173897454284, 0.7194553923324973, 0.7108390349297803
#          What?  CPU Cycles   Seconds
# 0         Init    0.022380  0.022380
# 1        Setup  274.028708  4.699657
# 2  Avg per Run    4.341454  0.067864
# 3    Total Run  434.145422  6.786394
# Changes caused by each step:
#                   Step  \
# 0  categorical_imputer
# 1    numerical_imputer
# 2     numerical_scaler
# 3            destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                                                                                  -
# 2  education-num, relationship, native-country, hours-per-week, race, occupation, marital-status, fnlwgt, workclass, age, capital-loss, capital-gain, education, sex
# 3                                                                                                                                                                  -
#
#    No of rows
# 0           0
# 1           0
# 2       24129
# 3           0
# Name: sc_destroyer_unscaled_minimal_adult_1.000000
# Dataset: adult
# Model: HGB
# Pipeline: ./pipelines/pickles/sc_destroyer/sc_destroyer_unscaled_minimal_1.000000.pkl
#
# Sample size: 100
# Samples: [200, 414, 480, 1080, 1303, 2000, 2046, 2252, 2462, 3352, 3663, 3967, 4099, 4573, 4662, 5165, 5261, 5421, 5595, 5975, 6142, 6392, 6743, 6847, 6871, 7132, 7225, 7289, 8180, 8204, 8292, 8758, 9341, 9522, 10047, 10178, 10500, 10694, 10899, 11479, 11509, 11597, 12010, 12764, 13048, 13353, 14043, 14166, 14425, 14620, 14943, 14967, 15031, 15923, 16139, 16240, 16354, 16723, 17189, 18227, 18552, 18633, 18640, 18897, 20280, 20293, 20945, 21048, 21186, 21343, 21352, 21544, 21614, 22493, 22808, 22956, 22997, 23291, 23582, 23617, 24440, 24518, 24591, 25327, 25572, 25648, 25741, 25832, 25956, 26016, 26431, 26480, 27137, 27558, 27798, 27981, 28443, 29032, 29317, 30158]
# Pipeline steps: categorical_encoder, categorical_imputer, numerical_imputer, numerical_scaler, destroyer
#
# Aggregated impacts: {'immediate_impact': [0.0023096345127463524, 0.003697789384448768, -0.001434201381495791, 0.9954267774843008], 'leave_out_impact': [0.004867592743071914, 0.014615755848485578, 0.004788231109480801, 0.9839870799240278]}
# F1 immediate_impact: 0.7133666904932094, 0.720456979650125, 0.7064784654361201, 0.7085137085137085, 0.6300148588410104
# F1 leave_out_impact: 0.6410066617320503, 0.6295327102803738, 0.6306373462541931, 0.7108390349297803
#          What?  CPU Cycles   Seconds
# 0         Init    0.021440  0.021440
# 1        Setup  269.554832  4.597711
# 2  Avg per Run    4.292901  0.067106
# 3    Total Run  429.290103  6.710586
# Changes caused by each step:
#                   Step  \
# 0  categorical_imputer
# 1    numerical_imputer
# 2     numerical_scaler
# 3            destroyer
#
#                                                                                                                                                       Which columns?  \
# 0                                                                                                                                                                  -
# 1                                                                                                                                                                  -
# 2  education-num, relationship, native-country, hours-per-week, race, occupation, marital-status, fnlwgt, workclass, age, capital-loss, capital-gain, education, sex
# 3                                                                                                              education-num, hours-per-week, age, capital-gain, sex
#
#    No of rows
# 0           0
# 1           0
# 2       24129
# 3       24129

# %%
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_0.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)
analyzer.display_feature_attribution(experiment_name=f'{EXPERIMENT_NAME}_adult_1.000000',
                                     dataset=EXPERIMENT_DATA,
                                     model='HGB',
                                     sample_size=DEFAULT_SAMPLE_SIZE,
                                     show_tables=SHOW_DETAIL_TABLES)

# %%
analyzer.inspect_step_across_experiments(step='destroyer',
                                         model='HGB',
                                         dataset=EXPERIMENT_DATA,
                                         sample_size=DEFAULT_SAMPLE_SIZE)
# Out:
# Tab(children=(HTML(value='<img src="...…
# Tab(children=(HTML(value='<img src="...…

# %% [markdown]
# Note
# - Feature weights for Leave Out Impact for Destroyer step across different Destroyer probabilities don't change because
#   Destroyer is not called a.k.a. left out.
# - Feature weights for One-by-one Impact for any step before Destroyer in pipeline, such as Replace Marital Status,
#   across different Destroyer probabilities don't change because Destroyer is not called as it is later in the pipeline.

# %%
for model in MODELS:
    analyzer.inspect_averages_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                 param_min=0.0, param_max=1)
# Out:
# Model: LR, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: KNN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: NN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: SVC, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1

# %%
for model in MODELS:
    analyzer.inspect_effects_across_experiments(model=model, dataset=EXPERIMENT_DATA, sample_size=DEFAULT_SAMPLE_SIZE,
                                                param_min=0.0, param_max=1)
# Out:
# Model: LR, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: DT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: GBT, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: KNN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: HGB, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: NN, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
# Model: SVC, Dataset: adult, Sample Size: 100, Experiment: None, Param: 0.0-1
